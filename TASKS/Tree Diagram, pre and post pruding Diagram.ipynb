# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Social_Network_Ads.csv")
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
data.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
sns.scatterplot(x="Age",y="EstimatedSalary", data=data,hue="Purchased")
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.histplot(data["EstimatedSalary"], kde=True)
plt.show()

# %%
data.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
# x=data.iloc[:,:-1]
# y=data["Purchased"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# from sklearn.linear_model import LogisticRegression

# %%
# lr=LogisticRegression()
# lr.fit(x_train,y_train)
# lr.score(x_test,y_test)*100

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x)
x=pd.DataFrame(sc.transform(x),columns=x.columns)
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier(max_depth=5)#max_depth is used to select the maximum leafs of the tree diagram
dc.fit(x_train,y_train)
dc.score(x_test,y_test)*100
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
dc1=DecisionTreeClassifier(criterion="entropy")
dc1.fit(x_train,y_train)
dc1.score(x_test,y_test)*100
# Out:
# 83.75

# %%
dc.predict([[27,57000]])
# Out:
# c:\Users\ravin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([0.])

# %%
for i in range (1,20):
    dc2=DecisionTreeClassifier(max_depth=i)# here we can identify at which step the accuracy of tree is high
    dc2.fit(x_train,y_train)
    print(dc2.score(x_test,y_test)*100,dc2.score(x_train,y_train)*100,i)
# Out:
# 57.85309971239143 36.44898975240045 1
# 63.39677809464725 70.3898889586138 2
# 66.67757195920572 72.98126138602194 3
# 71.24410922253293 76.70076516311936 4
# 71.11553601408902 79.99996219446035 5
# 46.1296753133488 85.79932333484825 6
# 36.60816035816037 89.59349593495935 7
# 35.00000000000001 92.57971014492755 8
# 34.224664224664224 94.34429126899964 9
# 34.75274725274726 95.92788971367975 10
# 27.19780219780221 97.55673382820784 11
# 28.57142857142858 98.64262990455993 12
# 27.19780219780221 98.64262990455993 13
# 28.57142857142858 99.32131495227996 14
# 28.57142857142858 99.32131495227996 15
# 28.57142857142858 99.32131495227996 16
# 28.57142857142858 99.32131495227996 17
# 28.57142857142858 99.32131495227996 18
# 28.57142857142858 99.32131495227996 19

# %%
dc3=DecisionTreeClassifier(max_depth=3)#max_depth is used to select the maximum leafs of the tree diagram
dc3.fit(x_train,y_train)
dc3.score(x_test,y_test)*100
# Out:
# 91.25

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(50,50))
plot_tree(dc3)
plt.savefig("tree_demo.jpg")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
